# %% [markdown]
# ## GRAFICOS EN 3D

# %% [markdown]
# Graficamos un mapa de calor

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Nos permite ingresar ejes tridimensionales en nuestra gráfica
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %% [markdown]
# Creamos figura

# %%
fig = plt.figure()
axl = fig.add_subplot(111, projection='3d')

# %% [markdown]
# Coordenada de barra

# %%
x = [1,2,3,4,2,6,7,8,9,10]
y = [3,4,6,7,1,2,5,9,10,5]
z = np.zeros(10)

dx = np.ones(10)
dy = np.ones(10)
dz = [2,3,4,3,4,5,3,7,8,2]

# %% [markdown]
# Presentacion de los datos

# %%
axl.bar3d(x, y, z, dx, dy, dz)
plt.show()
